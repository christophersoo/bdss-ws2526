# %% [markdown]
# <a href="https://colab.research.google.com/github/christophersoo/bdss-ws2526/blob/main/classes_gaps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Classes in Python

# %%
class Person:
  def intro(self):
    print("Hello, my name is ", self.name, ", nice to meet you!")

  def calc_bmi(self):
    # height in meters
    # weight in kilograms
    return self.weight / (self.height ** 2)

# %%
Amy = Person()

# %% [markdown]
# # Try running the code below and see what happens!

# %%
Amy.intro()
amy_bmi = Amy.calc_bmi()

# %% [markdown]
# # How can we give Amy her name, weight and height??

# %% [markdown]
# # The better way of doing it:

# %%
class BetterPerson:
  def __init__(self, n, w, h):
    self.name =  n
    self.weight = w
    self.height = h

  def intro(self):
    print("Hello, my name is ", self.name, ", nice to meet you!")

  def calc_bmi(self):
    return self.weight / (self.height ** 2)

# %% [markdown]
# # Based on the code below, what is John's weight and height?

# %%
John = BetterPerson("John", 70, 150)

# %% [markdown]
# # Run the code below and see what happens

# %%
print(John.name)
John.intro()
John.calc_bmi()
# Out:
# John
# Hello, my name is  John , nice to meet you!
# 0.003111111111111111

# %% [markdown]
# # Clinical Data System

# %%
class CDS:
  def __init__(self):
    self.data = {}
    self.metadata = {"age": 0, "sex": 1, "height": 2, "weight": 3}

  def add_row(self, id, age, sex, height, weight):
    self.data[id] = [age, sex, height, weight]

  def remove_row(self, id):
    del self.data[id]

  def get_entry(self, id, feature):
    # YOUR CODE
    return

  def change_entry(self, id, feature, new_value):
    # YOUR CODE HERE!
    pass

  def mean(self, feature):
    # YOUR CODE HERE!
    return

  def bmi(self, id):
    # YOUR CODE HERE!
    return
