# %% [markdown]
# <h1> Week 1: Introduction to Pandas </h1>
#
# <h4> Topic 1: Introduction to Pandas </h4>
# <h4>  Topic 2: Data Querying </h4>
# <h4>  Topic 3: Data Manipulating </h4>
# <h4>  Topic 4: Working with multiple tables </h4>
#
# ---

# %% [markdown]
# <h2>Topic 1: Introduction to Pandas</h2>
#
# ---
