# %% [markdown]
# ---
# <h1>Week 2: Practical Pandas</h1>
# <h2>Topic 1: Advanced Pandas</h2>
# <h2>Topic 2: Working with Messy Data</h2>
#
# ---

# %% [markdown]
# ---
# <h1>RECAP</h1>
#
# <h4>
# <ol>
#     <li>Numpy Arrays</li>
#     <li>Pandas Series</li>
#     <li>Pandas DataFrames</li>
#     <li>Basic Manipulation in Pandas DataFrames</li>
# </ol>
# </h4>
#
# ---

# %%
# If you haven't so

# !pip install pandas
# !pip install numpy
# Out:
# Requirement already satisfied: pandas in /home/chris/bdss/bdss-ws2526/bdss/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/chris/bdss/bdss-ws2526/bdss/lib/python3.12/site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/chris/bdss/bdss-ws2526/bdss/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/chris/bdss/bdss-ws2526/bdss/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/chris/bdss/bdss-ws2526/bdss/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/chris/bdss/bdss-ws2526/bdss/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /home/chris/bdss/bdss-ws2526/bdss/lib/python3.12/site-packages (2.4.1)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# <h2>This Week we will focus on advanced and practical pandas</h2>
#
# 1. Topic 1 (50 mins): Lambda Functions, Apply and Aggregation
# 2. Topic 2 (50 mins): Pandas Formatting and Null Inputting Strategies
#
# ---

# %% [markdown]
# ---
# <h2>Topic 1 </h2>
#
# ---
