# %% [markdown]
# # Modules in Python
#
# A module is simply a python file that has functions, classes and variables, when we import a module, we can essentially use the functions defined in that class
#
# We can only import files that are in the same project directory as us
#
# is "simple_add" file inside our project directory? Run the code below to find out!

# %%
# !ls
# Out:
# __pycache__  main.ipynb  simple_add.py

# %% [markdown]
# To call a function from a python file, we simply use the dot operator like below:

# %%
import simple_add

simple_add.add(2, 4)
# Out:
# 6

# %% [markdown]
# Check the file "simple_add" to understand, how can we find the standard deviation of the values: 10, 20, 10, 15 using "simple_add" module?

# %%
# Your code here

# %% [markdown]
# ## Tackling Problem 1

# %% [markdown]
# ### Average Function

# %%
# Example Input: [10, 20, 30]
# Example Output: 20
def avg(data:list):

    # your code here
    return 0

# %% [markdown]
# ### Conversion Function
#
# Here we're only dealing with units cm, m, g and kg
#
# the conversion are provided below:
#
# 1m = 100cm
# 1kg = 100g
#
# input and output should be strings with number and unit together
#
# for example:
#
# 100cm, 100m, 100g, 100kg

# %%
# Example Input: "120cm", "m"
# Example Output: "1.2m"

def conv(unit:str, target:str):

    # your code here
    return 0

# %% [markdown]
# ### BMI Function
#
# the formula for BMI is provided below:
#
# $BMI = \frac{\text{weight (kg)}}{\text{height (m)}^2}$

# %%
# Example Input: "150cm", "60000g"
# Example Output: "26.66666..."
def calc_bmi(height, weight):

    # your code here
    return 0

# %% [markdown]
# # Classes in Python

# %%
class Person:
  def intro(self):
    print("Hello, my name is ", self.name, ", nice to meet you!")

  def calc_bmi(self):
    # height in meters
    # weight in kilograms
    return self.weight / (self.height ** 2)

# %%
Amy = Person()

# %% [markdown]
# # Try running the code below and see what happens!

# %%
Amy.intro()
amy_bmi = Amy.calc_bmi()

# %% [markdown]
# # How can we give Amy her name, weight and height??

# %% [markdown]
# # The better way of doing it:

# %%
class BetterPerson:
  def __init__(self, n, w, h):
    self.name =  n
    self.weight = w
    self.height = h

  def intro(self):
    print("Hello, my name is ", self.name, ", nice to meet you!")

  def calc_bmi(self):
    return self.weight / (self.height ** 2)

# %% [markdown]
# # Based on the code below, what is John's weight and height?

# %%
John = BetterPerson("John", 70, 150)

# %% [markdown]
# # Run the code below and see what happens

# %%
print(John.name)
John.intro()
John.calc_bmi()
# Out:
# John
# Hello, my name is  John , nice to meet you!
# 0.003111111111111111

# %% [markdown]
# # Clinical Data System

# %%
class CDS:
  def __init__(self):
    self.data = {}
    self.metadata = {"age": 0, "sex": 1, "height": 2, "weight": 3}

  def add_row(self, id, age, sex, height, weight):
    self.data[id] = [age, sex, height, weight]

  def remove_row(self, id):
    del self.data[id]

  def get_entry(self, id, feature):
    # YOUR CODE
    return

  def change_entry(self, id, feature, new_value):
    # YOUR CODE HERE!
    pass

  def mean(self, feature):
    # YOUR CODE HERE!
    return

  def bmi(self, id):
    # YOUR CODE HERE!
    return
